# %%
import pandas as pd
import numpy as np
import inspect
import time
from itertools import combinations
from sklearn import model_selection,svm,metrics,linear_model
from sklearn.preprocessing import MinMaxScaler

from collections import defaultdict

# %%
def get_csv(ptnum,tube,markers):
    fcs = 'C:\\python27\\FCSlog10\\' + str(8*(ptnum-1)+tube) + '.csv'
    return np.genfromtxt(fcs, delimiter=',',usecols=markers)[1:,:].astype(int)

def histo(data):
    """
    Input array of cells x markers. Marker levels must already be converted to bin numbers, 
    i.e. signal of 815 of max 1000 is bin 8.
    For each cell, the bin numbers are combined into a combination specific to the n-dimensional
    hypercube in the n-dimensional data space. 
    i.e. Cell #415 has signal 457 for SSC and 180 for CD15. If we are only considering those 2
    markers, the 'index' for the 2-d histogram bin is '4,1'. 
    Defaultdict functions as a counter, incrementing for the appropriate bin index for every 
    cell in the array.    
    """
    
    d = defaultdict(int) 
    for cell in data:
        d[tuple(cell)] += 1
    return d

def scale_data(data):
    """
    MinMaxScaler normalizes data to 0-1. -1 to 1 may also be used, does not affect SVM results.
    """
    
    scale = MinMaxScaler()
    #scale = MaxAbsScaler()
    data = scale.fit_transform(data)
    #data = data[:,data.sum(axis=0)!=0] # drop 100% empty columns
    return data

def get_combo(tube,markers):
    """
    Input a given tube and set of markers to consider. 
    Calls histo() for every patient and adds the result as a new row in a df. 
    Returns 359 row df. Columns represent bin indexes. Data is counts of cells falling in those bins.
    """
    
    #start = time.time()
    combo_hist = pd.DataFrame(histo(get_csv(1,tube,markers)),index=[0])
    
    for ptnum in range(2,360):
        combo_hist.ix[ptnum-1,:] = histo(get_csv(ptnum,tube,markers))

    #print('combo complete - ' + str((time.time()-start)/60) + 'min')
    return combo_hist

def all_combos(tube,n_d):
    """
    Input tube and number of markers to consider.
    For every combination of markers (however many markers at a time we are considering),
    call tube_data() to get histo data for all cells for every patient for that combo.
    Iterate for every combo of markers and concat.
    Output is 359 patients x nCr dfs concat'ed horizontally, where m_columns in those 
    dfs depends on how many bins actually had cells (no cells in the bin for all 
    patients = not added to df).
    """    
    
    start = time.time()
    firstcombo = True
    tube_data = pd.DataFrame()
    for markers in combinations(range(1,8),n_d):
        if firstcombo == True:
            tube_data = get_combo(tube,markers)
            firstcombo = False
        else:
            tube_data = pd.concat([tube_data, get_combo(tube,markers)],axis = 1)
    tube_data = scale_data(tube_data.fillna(0))
    
    print('tube complete - ' + str((time.time()-start)/60) + 'min')
    return tube_data

def gridsearch(X,Y,algorithm,params,cv,scoring):
    """
    Grid search iterator for finding C.
    Input data, labels, algo (SVM), range of C to test, CV method, scoring method)
    Output result grid
    """                                
                                
    #start = time.time()
    grid = model_selection.GridSearchCV(algorithm, param_grid=params, cv=cv, scoring = scoring)
    grid.fit(X,Y)
    #print 'gridsearch: ' + str((time.time()-start)/60) + 'min'
    return pd.DataFrame(grid.cv_results_)

def split_and_fit(data):
    """
    Create preds from tube data generated from all_tubes().
    Input data from all_tubes(). 
    Create test folds of 72 (5 folds total). 
    For training 80% of data, run gridsearch and select C that produces highest test score.
    Use that C to predict on test fold.
    Repeat for remaining folds.  Add predictions to end of list of previous fold(s).
    Return 359 predictions.    
    """
    
    start = time.time()
    Y = pd.read_csv('C:\\python27\\CAPSTONE\\Y.csv')
    
    #Y = Y.drop(339,axis = 0).reset_index(drop = True)
    #data = np.delete(data,339,0)
    
    predictions = list()
    
    step = 72
    ptlist = range(0,Y.shape[0])[::step]
    
    for pt in ptlist:

        if pt == 180:
            print('pt 180 complete')
        
        try:
            XTRAIN, XTEST = np.delete(data, range(pt,pt+step), 0), data[pt:pt+step]
            YTRAIN = Y.drop(range(pt,pt+step),axis = 0).as_matrix().reshape(Y.shape[0]-step,)
        except ValueError: 
            print pt
            XTRAIN, XTEST = np.delete(data, range(pt,Y.shape[0]), 0), data[pt:Y.shape[0]]
            YTRAIN = Y.drop(range(pt,Y.shape[0]),axis = 0).as_matrix().reshape(pt,)
        
        hiC = 6
        lowC = -6
        
        f1_scorer = metrics.make_scorer(metrics.f1_score, labels=['aml','normal'], pos_label='aml')
        algorithm, params, scoring = svm.LinearSVC(), {'C': np.logspace(lowC, hiC, hiC-lowC+1, endpoint=True)}, f1_scorer
        cv = model_selection.StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)
        results = gridsearch(XTRAIN, YTRAIN, algorithm, params, cv, scoring)
        
        #gamma = results.ix[results['mean_test_score'].idxmax(),5]
        C = results.ix[results['mean_test_score'].idxmax(),4]
        #if (C==10**hiC)|(C==10**lowC):
        print C
                
        linSVC = svm.LinearSVC(C = C)
        linSVC.fit(XTRAIN,YTRAIN)
        predictions.extend(linSVC.predict(XTEST))
        #predictions.extend(list(logREG.predict_proba(XTEST)[:,0]))
    print 'split_and_fit: ' + str((time.time()-start)/60) + 'min'
    return predictions

def pred_map(n_d):
    """
    Create 359 x 8 map. First column is true label for all patients (gold standard). 
    Remaining columns are preds corresponding to 1 tube per column.
    Also return a separate master list of preds based on this map where if any one tube was 
    called positive, the master pred was positive.
    """
                                
    master = pd.read_csv('C:\\python27\\CAPSTONE\\Y.csv')
    
    for tube in range(1,8):
        data = all_combos(tube, n_d)
        master[tube] = split_and_fit(data)
        print('Tube ' + str(tube) + ' complete')
    
    predictions = []
    for i in range(0,359):
        if 'aml' in master[range(1,8)].loc[i].values.tolist():
            predictions.extend(['aml'])
        else: 
            predictions.extend(['normal'])
    return master,predictions

def f1(YPRED):
    """
    f1 function = 2 * harmonic mean of recall and precision.
    Input list of preds.
    Compare with gold standard labels.
    Output f1, recall, precision, TP, FP, FN
    """
                                
    Y = pd.read_csv('C:\\python27\\CAPSTONE\\Y.csv')
    YTEST = Y['Condition'].tolist()
    TP, FN, FP = 0., 0., 0.
    for i in range(0,len(YTEST)):
        if (YTEST[i] == 'aml') and (YPRED[i]=='aml'):
            TP += 1
        if (YTEST[i] == 'aml') and (YPRED[i]=='normal'):    
            FN += 1
        if (YTEST[i] == 'normal') and (YPRED[i]=='aml'):
            FP += 1
    try: 
        recall = TP / (TP + FN)
        precision = TP / (TP + FP)
        f1 = 2 * (recall * precision) / (recall + precision)
    except ZeroDivisionError:
        return 0
        
    return f1, recall, precision, TP, FP, FN

# %%
Y, predictions = pred_map(3)
Y.to_csv("C:\\python27\\3dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
pd.options.display.max_rows = 360
f1(predictions)
# Out:
# combo complete - 1.04468333324min
# combo complete - 1.064016668min
# combo complete - 1.15016666651min
# combo complete - 1.12088333368min
# combo complete - 1.1158833305min
# combo complete - 1.10931666692min
# combo complete - 1.10715000232min
# combo complete - 1.1162833333min
# combo complete - 1.11721666654min
# combo complete - 1.11735000213min
# combo complete - 1.10546666781min
# combo complete - 1.1165833354min
# combo complete - 1.08718333244min
# combo complete - 1.08571666479min
# combo complete - 1.06233333349min
# combo complete - 1.08008333445min
# combo complete - 1.04293333292min
# combo complete - 1.04931666454min
# combo complete - 1.07291666667min
# combo complete - 1.04308333397min
# combo complete - 1.05618333419min
# combo complete - 1.04115000168min
# combo complete - 1.02901666562min
# combo complete - 1.02471666733min
# combo complete - 1.03848333359min
# combo complete - 1.03248333136min
# combo complete - 1.02808333635min
# combo complete - 1.02480000257min
# combo complete - 1.03744999965min
# combo complete - 1.03660000165min
# combo complete - 1.02199999889min
# combo complete - 1.02905000051min
# combo complete - 1.03971666495min
# combo complete - 1.03265000184min
# combo complete - 1.21096666654min
# tube complete - 37.4995500008min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.306583333015min
# Tube 1 complete
# combo complete - 1.16535000006min
# combo complete - 1.04248332977min
# combo complete - 1.06548333565min
# combo complete - 1.07804999749min
# combo complete - 1.07203333378min
# combo complete - 1.10113333464min
# combo complete - 1.1194999973min
# combo complete - 1.08544999758min
# combo complete - 1.07015000184min
# combo complete - 1.08346666495min
# combo complete - 1.0846666654min
# combo complete - 1.0778666695min
# combo complete - 1.06993333101min
# combo complete - 1.0638166666min
# combo complete - 1.07671666543min
# combo complete - 1.08291666905min
# combo complete - 1.07648333311min
# combo complete - 1.06515000264min
# combo complete - 1.06378333171min
# combo complete - 1.07704999844min
# combo complete - 1.04101667007min
# combo complete - 1.04048333565min
# combo complete - 1.04078333378min
# combo complete - 1.0451666673min
# combo complete - 1.05994999806min
# combo complete - 1.07113333543min
# combo complete - 1.09346666733min
# combo complete - 1.12811666727min
# combo complete - 1.09860000213min
# combo complete - 1.10646666686min
# combo complete - 1.08606666724min
# combo complete - 1.07724999984min
# combo complete - 1.06201666594min
# combo complete - 1.07043333451min
# combo complete - 1.06436666648min
# tube complete - 37.7197333336min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.401750000318min
# Tube 2 complete
# combo complete - 1.06261666616min
# combo complete - 1.05021666686min
# combo complete - 1.09948333502min
# combo complete - 1.09184999863min
# combo complete - 1.07753333251min
# combo complete - 1.10406666597min
# combo complete - 1.06974999905min
# combo complete - 1.08238333464min
# combo complete - 1.08918333054min
# combo complete - 1.07763333321min
# combo complete - 1.06418333054min
# combo complete - 1.09610000054min
# combo complete - 1.08713333607min
# combo complete - 1.09063333273min
# combo complete - 1.07423333327min
# combo complete - 1.08318333228min
# combo complete - 1.08509999911min
# combo complete - 1.06793333292min
# combo complete - 1.06696666876min
# combo complete - 1.07591666381min
# combo complete - 1.05883333286min
# combo complete - 1.06069999933min
# combo complete - 1.06085000038min
# combo complete - 1.06310000022min
# combo complete - 1.05868333578min
# combo complete - 1.11929999987min
# combo complete - 1.11865000327min
# combo complete - 1.10518333117min
# combo complete - 1.12254999876min
# combo complete - 1.12206666867min
# combo complete - 1.11248333454min
# combo complete - 1.11856666803min
# combo complete - 1.11545000076min
# combo complete - 1.09903333187min
# combo complete - 1.11911666791min
# tube complete - 38.0640000025min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.459983332952min
# Tube 3 complete
# combo complete - 1.13118333419min
# combo complete - 1.12626666625min
# combo complete - 1.10751666625min
# combo complete - 1.11938333114min
# combo complete - 1.12288333178min
# combo complete - 1.13026666641min
# combo complete - 1.12846666574min
# combo complete - 1.16463333368min
# combo complete - 1.14666666587min
# combo complete - 1.11021666924min
# combo complete - 1.10263333321min
# combo complete - 1.12854999701min
# combo complete - 1.09678333203min
# combo complete - 1.09660000006min
# combo complete - 1.092233332min
# combo complete - 1.08876666625min
# combo complete - 1.09429999987min
# combo complete - 1.11191666524min
# combo complete - 1.11308333476min
# combo complete - 1.12999999921min
# combo complete - 1.10860000054min
# combo complete - 1.09298333327min
# combo complete - 1.09428333441min
# combo complete - 1.09730000099min
# combo complete - 1.10324999889min
# combo complete - 1.09853333235min
# combo complete - 1.11098333597min
# combo complete - 1.10033333302min
# combo complete - 1.09276666641min
# combo complete - 1.10278333028min
# combo complete - 1.10638333559min
# combo complete - 1.10463333527min
# combo complete - 1.1074000001min
# combo complete - 1.11220000188min
# combo complete - 1.10663333337min
# tube complete - 38.8968333324min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.404866663615min
# Tube 4 complete
# combo complete - 1.10931666692min
# combo complete - 1.1113833348min
# combo complete - 1.10218333006min
# combo complete - 1.10479999781min
# combo complete - 1.10249999762min
# combo complete - 1.09845000108min
# combo complete - 1.11440000137min
# combo complete - 1.10858333508min
# combo complete - 1.09906666676min
# combo complete - 1.1049333334min
# combo complete - 1.1099333326min
# combo complete - 1.11523333391min
# combo complete - 1.10326666832min
# combo complete - 1.10070000092min
# combo complete - 1.09683333238min
# combo complete - 1.12278333108min
# combo complete - 1.11623333295min
# combo complete - 1.10616666873min
# combo complete - 1.10590000153min
# combo complete - 1.11749999921min
# combo complete - 1.10164999962min
# combo complete - 1.10164999962min
# combo complete - 1.09484999975min
# combo complete - 1.11446666718min
# combo complete - 1.10240000089min
# combo complete - 1.07379999955min
# combo complete - 1.09193333387min
# combo complete - 1.10214999914min
# combo complete - 1.09086666902min
# combo complete - 1.10526666641min
# combo complete - 1.07421666384min
# combo complete - 1.10088333686min
# combo complete - 1.09579999844min
# combo complete - 1.08031666676min
# combo complete - 1.08585000038min
# tube complete - 38.5789166649min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.320266668002min
# Tube 5 complete
# combo complete - 1.10253333648min
# combo complete - 1.12248333295min
# combo complete - 1.12543333371min
# combo complete - 1.10385000308min
# combo complete - 1.10828333298min
# combo complete - 1.08656666676min
# combo complete - 1.1002000014min
# combo complete - 1.08168333371min
# combo complete - 1.09338333209min
# combo complete - 1.09960000118min
# combo complete - 1.10575000048min
# combo complete - 1.10264999866min
# combo complete - 1.15998333295min
# combo complete - 1.14221667051min
# combo complete - 1.10828333298min
# combo complete - 1.08228333394min
# combo complete - 1.08656666676min
# combo complete - 1.1037833333min
# combo complete - 1.11481666565min
# combo complete - 1.09018333356min
# combo complete - 1.07951666514min
# combo complete - 1.12753333648min
# combo complete - 1.14185000261min
# combo complete - 1.12313332955min
# combo complete - 1.10441666842min
# combo complete - 1.10208333333min
# combo complete - 1.08905000289min
# combo complete - 1.10428333282min
# combo complete - 1.07846666574min
# combo complete - 1.07836666505min
# combo complete - 1.11660000086min
# combo complete - 1.09041666985min
# combo complete - 1.08939999739min
# combo complete - 1.08339999914min
# combo complete - 1.09465000232min
# tube complete - 38.6375500003min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.355516664187min
# Tube 6 complete
# combo complete - 1.10918333133min
# combo complete - 1.0752000014min
# combo complete - 1.08619999886min
# combo complete - 1.06878333489min
# combo complete - 1.09133332968min
# combo complete - 1.08658333619min
# combo complete - 1.10549999873min
# combo complete - 1.09113333623min
# combo complete - 1.07248333693min
# combo complete - 1.09956666629min
# combo complete - 1.0861833334min
# combo complete - 1.09738333623min
# combo complete - 1.10154999892min
# combo complete - 1.0887166659min
# combo complete - 1.09566666683min
# combo complete - 1.09464999835min
# combo complete - 1.08368333181min
# combo complete - 1.08338333368min
# combo complete - 1.08273333311min
# combo complete - 1.08595000108min
# combo complete - 1.08088333607min
# combo complete - 1.06850000223min
# combo complete - 1.08721666733min
# combo complete - 1.06948333184min
# combo complete - 1.06728333632min
# combo complete - 1.0589166681min
# combo complete - 1.06359999975min
# combo complete - 1.07803333203min
# combo complete - 1.0798333327min
# combo complete - 1.08820000092min
# combo complete - 1.06730000178min
# combo complete - 1.10343333483min
# combo complete - 1.09416666826min
# combo complete - 1.08593333165min
# combo complete - 1.10326666435min
# tube complete - 37.9951333324min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.353550000985min
# Tube 7 complete
# (0.898876404494382, 0.9302325581395349, 0.8695652173913043, 40.0, 6.0, 3.0)

# %%
Y, predictions = pred_map(4)
Y.to_csv("C:\\python27\\4dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
pd.options.display.max_rows = 360
f1(predictions)
# Out:
# tube complete - 48.3627999981min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.595850002766min
# Tube 1 complete
# tube complete - 44.725516665min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.992533334096min
# Tube 2 complete
# tube complete - 46.2189833323min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.00821666718min
# Tube 3 complete
# tube complete - 46.5275333325min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.12939999898min
# Tube 4 complete
# tube complete - 46.1878833334min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.885716668765min
# Tube 5 complete
# tube complete - 45.3568833311min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.0409166654min
# Tube 6 complete
# tube complete - 44.6849499981min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.860750003656min
# Tube 7 complete
# (0.9195402298850575, 0.9302325581395349, 0.9090909090909091, 40.0, 4.0, 3.0)

# %%
Y, predictions = pred_map(5)
Y.to_csv("C:\\python27\\5dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
pd.options.display.max_rows = 360
f1(predictions)
# Out:
# tube complete - 30.4176333348min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.583716666698min
# Tube 1 complete
# tube complete - 29.8738666693min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.989383331935min
# Tube 2 complete
# tube complete - 30.1121333321min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.14814999898min
# Tube 3 complete
# tube complete - 30.5892500003min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.24671666622min
# Tube 4 complete
# tube complete - 29.9484500011min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.985649998983min
# Tube 5 complete
# tube complete - 30.4602666696min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 1.25043332974min
# Tube 6 complete
# tube complete - 29.7151166677min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.959666665395min
# Tube 7 complete
# (0.963855421686747, 0.9302325581395349, 1.0, 40.0, 0.0, 3.0)

# %%
Y, predictions = pred_map(6)
Y.to_csv("C:\\python27\\6dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
pd.options.display.max_rows = 360
f1(predictions)
# Out:
# tube complete - 11.2517833352min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.324616666635min
# Tube 1 complete
# tube complete - 11.7448166649min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.519366665681min
# Tube 2 complete
# tube complete - 11.8004999995min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.59361666441min
# Tube 3 complete
# tube complete - 12.342383333min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.613933336735min
# Tube 4 complete
# tube complete - 11.8678333322min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.501916666826min
# Tube 5 complete
# tube complete - 12.1205833356min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.643833335241min
# Tube 6 complete
# tube complete - 11.6261333307min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.504700001081min
# Tube 7 complete
# (0.9761904761904763, 0.9534883720930233, 1.0, 41.0, 0.0, 2.0)

# %%
Y, predictions = pred_map(7)
Y.to_csv("C:\\python27\\7dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
pd.options.display.max_rows = 360
f1(predictions)
# Out:
# tube complete - 1.87073333263min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.0844499985377min
# Tube 1 complete
# tube complete - 1.99468333324min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.115566666921min
# Tube 2 complete
# tube complete - 2.01041666667min
# 10.0
# 100.0
# 100.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.124550000827min
# Tube 3 complete
# tube complete - 2.12708333333min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.123233334223min
# Tube 4 complete
# tube complete - 2.02884999911min
# 10.0
# 10.0
# 10.0
# 100.0
# 288
# 10.0
# split_and_fit: 0.108416668574min
# Tube 5 complete
# tube complete - 2.08779999812min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.131016667684min
# Tube 6 complete
# tube complete - 1.96243333419min
# 10.0
# 10.0
# 10.0
# 10.0
# 288
# 10.0
# split_and_fit: 0.11318333149min
# Tube 7 complete
# (0.8602150537634408, 0.9302325581395349, 0.8, 40.0, 10.0, 3.0)

# %%
Y = pd.read_csv("C:\\python27\\6dhist5fold.csv")
Y.insert(1,"Ypred",predictions)
Y
# Out:
#      Unnamed: 0   Ypred Condition       1       2       3       4       5  \
# 0             0  normal    normal  normal  normal  normal  normal  normal
# 1             1  normal    normal  normal  normal  normal  normal  normal
# 2             2  normal    normal  normal  normal  normal  normal  normal
# 3             3  normal    normal  normal  normal  normal  normal  normal
# 4             4     aml       aml  normal     aml  normal     aml     aml
# 5             5  normal    normal  normal  normal  normal  normal  normal
# 6             6  normal       aml  normal  normal  normal  normal  normal
# 7             7  normal    normal  normal  normal  normal  normal  normal
# 8             8     aml       aml     aml     aml     aml     aml     aml
# 9             9  normal    normal  normal  normal  normal  normal  normal
# 10           10  normal    normal  normal  normal  normal  normal  normal
# 11           11  normal    normal  normal  normal  normal  normal  normal
# 12           12  normal    normal  normal  normal  normal  normal  normal
# 13           13  normal    normal  normal  normal  normal  normal  normal
# 14           14  normal    normal  normal  normal  normal  normal  normal
# 15           15  normal    normal  normal  normal  normal  normal  normal
# 16           16  normal    normal  normal  normal  normal  normal  normal
# 17           17  normal    normal  normal  normal  normal  normal  normal
# 18           18  normal    normal  normal  normal  normal  normal  normal
# 19           19  normal    normal  normal  normal  normal  normal  normal
# 20           20  normal    normal  normal  normal  normal  normal  normal
# 21           21  normal    normal  normal  normal  normal  normal  normal
# 22           22  normal    normal  normal  normal  normal  normal  normal
# 23           23  normal    normal  normal  normal  normal  normal  normal
# 24           24  normal    normal  normal  normal  normal  normal  normal
# 25           25     aml       aml     aml     aml     aml     aml     aml
# 26           26  normal    normal  normal  normal  normal  normal  normal
# 27           27  normal    normal  normal  normal  normal  normal  normal
# 28           28  normal    normal  normal  normal  normal  normal  normal
# 29           29  normal    normal  normal  normal  normal  normal  normal
# 30           30  normal    normal  normal  normal  normal  normal  normal
# 31           31  normal    normal  normal  normal  normal  normal  normal
# 32           32     aml       aml     aml     aml     aml     aml     aml
# 33           33  normal    normal  normal  normal  normal  normal  normal
# 34           34  normal    normal  normal  normal  normal  normal  normal
# 35           35  normal    normal  normal  normal  normal  normal  normal
# 36           36     aml       aml     aml     aml     aml     aml     aml
# 37           37  normal    normal  normal  normal  normal  normal  normal
# 38           38  normal    normal  normal  normal  normal  normal  normal
# 39           39  normal    normal  normal  normal  normal  normal  normal
# 40           40  normal    normal  normal  normal  normal  normal  normal
# 41           41  normal    normal  normal  normal  normal  normal  normal
# 42           42  normal    normal  normal  normal  normal  normal  normal
# 43           43  normal    normal  normal  normal  normal  normal  normal
# 44           44  normal    normal  normal  normal  normal  normal  normal
# 45           45  normal    normal  normal  normal  normal  normal  normal
# 46           46  normal    normal  normal  normal  normal  normal  normal
# 47           47  normal    normal  normal  normal  normal  normal  normal
# 48           48     aml       aml     aml     aml     aml     aml     aml
# 49           49  normal    normal  normal  normal  normal  normal  normal
# 50           50  normal    normal  normal  normal  normal  normal  normal
# 51           51  normal    normal  normal  normal  normal  normal  normal
# 52           52  normal    normal  normal  normal  normal  normal  normal
# 53           53  normal    normal  normal  normal  normal  normal  normal
# 54           54  normal    normal  normal  normal  normal  normal  normal
# 55           55  normal    normal  normal  normal  normal  normal  normal
# 56           56  normal    normal  normal  normal  normal  normal  normal
# 57           57     aml       aml     aml     aml     aml     aml     aml
# 58           58  normal    normal  normal  normal  normal  normal  normal
# 59           59  normal       aml  normal  normal     aml  normal  normal
# 60           60  normal    normal  normal  normal  normal  normal  normal
# 61           61     aml    normal  normal  normal  normal  normal  normal
# 62           62  normal    normal  normal  normal  normal  normal  normal
# 63           63  normal    normal  normal  normal  normal  normal  normal
# 64           64  normal    normal  normal  normal  normal  normal  normal
# 65           65  normal    normal  normal  normal  normal  normal  normal
# 66           66     aml       aml     aml     aml     aml     aml     aml
# 67           67  normal    normal  normal  normal  normal  normal  normal
# 68           68  normal    normal  normal  normal  normal  normal  normal
# 69           69  normal    normal  normal  normal  normal  normal  normal
# 70           70  normal    normal  normal  normal  normal  normal  normal
# 71           71  normal    normal  normal  normal  normal  normal  normal
# 72           72  normal    normal  normal  normal  normal  normal  normal
# 73           73  normal    normal  normal  normal  normal  normal  normal
# 74           74  normal    normal  normal  normal  normal  normal  normal
# 75           75  normal    normal  normal  normal  normal  normal  normal
# 76           76  normal    normal  normal  normal  normal  normal  normal
# 77           77  normal    normal  normal  normal  normal  normal  normal
# 78           78  normal    normal  normal  normal  normal  normal  normal
# 79           79  normal    normal  normal  normal  normal  normal  normal
# 80           80  normal    normal  normal  normal  normal  normal  normal
# 81           81  normal    normal  normal  normal  normal  normal  normal
# 82           82  normal    normal  normal  normal  normal  normal  normal
# 83           83  normal    normal  normal  normal  normal  normal  normal
# 84           84  normal    normal  normal  normal  normal  normal  normal
# 85           85  normal    normal  normal  normal  normal  normal  normal
# 86           86  normal    normal  normal  normal  normal  normal  normal
# 87           87     aml       aml     aml     aml     aml     aml     aml
# 88           88     aml       aml     aml     aml     aml     aml     aml
# 89           89  normal    normal  normal  normal  normal  normal  normal
# 90           90  normal    normal  normal  normal  normal  normal  normal
# 91           91  normal    normal  normal  normal  normal  normal  normal
# 92           92  normal    normal  normal  normal  normal  normal  normal
# 93           93  normal    normal  normal  normal  normal  normal  normal
# 94           94     aml       aml     aml     aml     aml     aml     aml
# 95           95  normal    normal  normal  normal  normal  normal  normal
# 96           96  normal    normal  normal  normal  normal  normal  normal
# 97           97  normal    normal  normal  normal  normal  normal  normal
# 98           98  normal    normal  normal  normal  normal  normal  normal
# 99           99  normal    normal  normal  normal  normal  normal  normal
# 100         100     aml       aml  normal  normal  normal  normal     aml
# 101         101  normal    normal  normal  normal  normal  normal  normal
# 102         102     aml       aml  normal  normal     aml     aml     aml
# 103         103  normal    normal  normal  normal  normal  normal  normal
# 104         104     aml       aml     aml     aml     aml     aml     aml
# 105         105     aml    normal  normal  normal  normal  normal  normal
# 106         106  normal    normal  normal  normal  normal  normal  normal
# 107         107  normal    normal  normal  normal  normal  normal  normal
# 108         108  normal    normal  normal  normal  normal  normal  normal
# 109         109  normal    normal  normal  normal  normal  normal  normal
# 110         110  normal    normal  normal  normal  normal  normal  normal
# 111         111  normal    normal  normal  normal  normal  normal  normal
# 112         112  normal    normal  normal  normal  normal  normal  normal
# 113         113  normal    normal  normal  normal  normal  normal  normal
# 114         114  normal    normal  normal  normal  normal  normal  normal
# 115         115  normal       aml  normal  normal  normal  normal  normal
# 116         116     aml       aml     aml     aml     aml     aml     aml
# 117         117  normal    normal  normal  normal  normal  normal  normal
# 118         118  normal    normal  normal  normal  normal  normal  normal
# 119         119  normal    normal  normal  normal  normal  normal  normal
# 120         120  normal    normal  normal  normal  normal  normal  normal
# 121         121  normal    normal  normal  normal  normal  normal  normal
# 122         122  normal    normal  normal  normal  normal  normal  normal
# 123         123  normal    normal  normal  normal  normal  normal  normal
# 124         124  normal    normal  normal  normal  normal  normal  normal
# 125         125  normal    normal  normal  normal  normal  normal  normal
# 126         126  normal    normal  normal  normal  normal  normal  normal
# 127         127  normal    normal  normal  normal  normal  normal  normal
# 128         128  normal    normal  normal  normal  normal  normal  normal
# 129         129  normal    normal  normal  normal  normal  normal  normal
# 130         130  normal    normal  normal  normal  normal  normal  normal
# 131         131  normal    normal  normal  normal  normal  normal  normal
# 132         132  normal    normal  normal  normal  normal  normal  normal
# 133         133     aml       aml     aml     aml     aml     aml     aml
# 134         134  normal    normal  normal  normal  normal  normal  normal
# 135         135  normal    normal  normal  normal  normal  normal  normal
# 136         136  normal    normal  normal  normal  normal  normal  normal
# 137         137  normal    normal  normal  normal  normal  normal  normal
# 138         138  normal    normal  normal  normal  normal  normal  normal
# 139         139  normal    normal  normal  normal  normal  normal  normal
# 140         140  normal    normal  normal  normal  normal  normal  normal
# 141         141  normal    normal  normal  normal  normal  normal  normal
# 142         142  normal    normal  normal  normal  normal  normal  normal
# 143         143  normal    normal  normal  normal  normal  normal  normal
# 144         144  normal    normal  normal  normal  normal  normal  normal
# 145         145  normal    normal  normal  normal  normal  normal  normal
# 146         146  normal    normal  normal  normal  normal  normal  normal
# 147         147  normal    normal  normal  normal  normal  normal  normal
# 148         148  normal    normal  normal  normal  normal  normal  normal
# 149         149  normal    normal  normal  normal  normal  normal  normal
# 150         150     aml       aml     aml     aml     aml     aml     aml
# 151         151  normal    normal  normal  normal  normal  normal  normal
# 152         152  normal    normal  normal  normal  normal  normal  normal
# 153         153  normal    normal  normal  normal  normal  normal  normal
# 154         154  normal    normal  normal  normal  normal  normal  normal
# 155         155  normal    normal  normal  normal  normal  normal  normal
# 156         156  normal    normal  normal  normal  normal  normal  normal
# 157         157  normal    normal  normal  normal  normal  normal  normal
# 158         158  normal    normal  normal  normal  normal  normal  normal
# 159         159  normal    normal  normal  normal  normal  normal  normal
# 160         160  normal    normal  normal  normal  normal  normal  normal
# 161         161  normal    normal  normal  normal  normal  normal  normal
# 162         162  normal    normal  normal  normal  normal  normal  normal
# 163         163  normal    normal  normal  normal  normal  normal  normal
# 164         164     aml       aml     aml     aml     aml     aml     aml
# 165         165  normal    normal  normal  normal  normal  normal  normal
# 166         166     aml    normal  normal  normal  normal  normal  normal
# 167         167  normal    normal  normal  normal  normal  normal  normal
# 168         168  normal    normal  normal  normal  normal  normal  normal
# 169         169  normal    normal  normal  normal  normal  normal  normal
# 170         170  normal    normal  normal  normal  normal  normal  normal
# 171         171     aml       aml     aml     aml     aml     aml     aml
# 172         172  normal    normal  normal  normal  normal  normal  normal
# 173         173     aml       aml     aml     aml     aml     aml  normal
# 174         174  normal    normal  normal  normal  normal  normal  normal
# 175         175  normal    normal  normal  normal  normal  normal  normal
# 176         176  normal    normal  normal  normal  normal  normal  normal
# 177         177  normal    normal  normal  normal  normal  normal  normal
# 178         178  normal    normal  normal  normal  normal  normal  normal
# 179         179  normal    normal  normal  normal  normal  normal  normal
# 180         180  normal    normal  normal  normal  normal  normal  normal
# 181         181  normal    normal  normal  normal  normal  normal  normal
# 182         182     aml    normal  normal  normal  normal  normal  normal
# 183         183  normal    normal  normal  normal  normal  normal  normal
# 184         184  normal    normal  normal  normal  normal  normal  normal
# 185         185  normal    normal  normal  normal  normal  normal  normal
# 186         186     aml    normal  normal  normal  normal  normal  normal
# 187         187  normal    normal  normal  normal  normal  normal  normal
# 188         188  normal    normal  normal  normal  normal  normal  normal
# 189         189  normal    normal  normal  normal  normal  normal  normal
# 190         190  normal    normal  normal  normal  normal  normal  normal
# 191         191  normal    normal  normal  normal  normal  normal  normal
# 192         192  normal    normal  normal  normal  normal  normal  normal
# 193         193     aml    normal  normal  normal  normal  normal  normal
# 194         194  normal    normal  normal  normal  normal  normal  normal
# 195         195  normal    normal  normal  normal  normal  normal  normal
# 196         196  normal    normal  normal  normal  normal  normal  normal
# 197         197  normal    normal  normal  normal  normal  normal  normal
# 198         198  normal    normal  normal  normal  normal  normal  normal
# 199         199  normal    normal  normal  normal  normal  normal  normal
# 200         200  normal    normal  normal  normal  normal  normal  normal
# 201         201  normal    normal  normal  normal  normal  normal  normal
# 202         202     aml       aml     aml     aml     aml     aml     aml
# 203         203  normal    normal  normal  normal  normal  normal  normal
# 204         204     aml       aml     aml     aml     aml     aml     aml
# 205         205  normal    normal  normal  normal  normal  normal  normal
# 206         206  normal    normal  normal  normal  normal  normal  normal
# 207         207  normal    normal  normal  normal  normal  normal  normal
# 208         208  normal    normal  normal  normal  normal  normal  normal
# 209         209  normal    normal  normal  normal  normal  normal  normal
# 210         210     aml       aml     aml     aml     aml     aml     aml
# 211         211  normal    normal  normal  normal  normal  normal  normal
# 212         212  normal    normal  normal  normal  normal  normal  normal
# 213         213  normal    normal  normal  normal  normal  normal  normal
# 214         214  normal    normal  normal  normal  normal  normal  normal
# 215         215  normal    normal  normal  normal  normal  normal  normal
# 216         216  normal    normal  normal  normal  normal  normal  normal
# 217         217  normal    normal  normal  normal  normal  normal  normal
# 218         218     aml       aml     aml     aml     aml     aml     aml
# 219         219  normal    normal  normal  normal  normal  normal  normal
# 220         220     aml       aml     aml     aml     aml     aml     aml
# 221         221     aml    normal  normal  normal  normal  normal  normal
# 222         222  normal    normal  normal  normal  normal  normal  normal
# 223         223  normal    normal  normal  normal  normal  normal  normal
# 224         224  normal    normal  normal  normal  normal  normal  normal
# 225         225  normal    normal  normal  normal  normal  normal  normal
# 226         226     aml       aml     aml     aml     aml     aml     aml
# 227         227     aml    normal  normal  normal  normal  normal  normal
# 228         228  normal    normal  normal  normal  normal  normal  normal
# 229         229  normal    normal  normal  normal  normal  normal  normal
# 230         230  normal    normal  normal  normal  normal  normal  normal
# 231         231  normal    normal  normal  normal  normal  normal  normal
# 232         232  normal    normal  normal  normal  normal  normal  normal
# 233         233  normal    normal  normal  normal  normal  normal  normal
# 234         234  normal    normal  normal  normal  normal  normal  normal
# 235         235     aml       aml     aml     aml  normal     aml  normal
# 236         236  normal    normal  normal  normal  normal  normal  normal
# 237         237  normal    normal  normal  normal  normal  normal  normal
# 238         238     aml       aml     aml  normal     aml     aml  normal
# 239         239  normal    normal  normal  normal  normal  normal  normal
# 240         240  normal    normal  normal  normal  normal  normal  normal
# 241         241  normal    normal  normal  normal  normal  normal  normal
# 242         242  normal    normal  normal  normal  normal  normal  normal
# 243         243  normal    normal  normal  normal  normal  normal  normal
# 244         244  normal    normal  normal  normal  normal  normal  normal
# 245         245  normal    normal  normal  normal  normal  normal  normal
# 246         246  normal    normal  normal  normal  normal  normal  normal
# 247         247  normal    normal  normal  normal  normal  normal  normal
# 248         248  normal    normal  normal  normal  normal  normal  normal
# 249         249     aml    normal  normal  normal  normal  normal  normal
# 250         250  normal    normal  normal  normal  normal  normal  normal
# 251         251  normal    normal  normal  normal  normal  normal  normal
# 252         252  normal    normal  normal  normal  normal  normal  normal
# 253         253  normal    normal  normal  normal  normal  normal  normal
# 254         254  normal    normal  normal  normal  normal  normal  normal
# 255         255  normal    normal  normal  normal  normal  normal  normal
# 256         256  normal    normal  normal  normal  normal  normal  normal
# 257         257  normal    normal  normal  normal  normal  normal  normal
# 258         258  normal    normal  normal  normal  normal  normal  normal
# 259         259  normal    normal  normal  normal  normal  normal  normal
# 260         260     aml       aml     aml     aml     aml     aml     aml
# 261         261     aml       aml     aml     aml     aml     aml     aml
# 262         262  normal    normal  normal  normal  normal  normal  normal
# 263         263  normal    normal  normal  normal  normal  normal  normal
# 264         264  normal    normal  normal  normal  normal  normal  normal
# 265         265  normal    normal  normal  normal  normal  normal  normal
# 266         266  normal    normal  normal  normal  normal  normal  normal
# 267         267  normal    normal  normal  normal  normal  normal  normal
# 268         268     aml       aml     aml     aml     aml     aml     aml
# 269         269  normal    normal  normal  normal  normal  normal  normal
# 270         270  normal    normal  normal  normal  normal  normal  normal
# 271         271  normal    normal  normal  normal  normal  normal  normal
# 272         272  normal    normal  normal  normal  normal  normal  normal
# 273         273  normal    normal  normal  normal  normal  normal  normal
# 274         274  normal    normal  normal  normal  normal  normal  normal
# 275         275  normal    normal  normal  normal  normal  normal  normal
# 276         276  normal    normal  normal  normal  normal  normal  normal
# 277         277  normal    normal  normal  normal  normal  normal  normal
# 278         278  normal    normal  normal  normal  normal  normal  normal
# 279         279  normal    normal  normal  normal  normal  normal  normal
# 280         280  normal    normal  normal  normal  normal  normal  normal
# 281         281  normal    normal  normal  normal  normal  normal  normal
# 282         282  normal    normal  normal  normal  normal  normal  normal
# 283         283     aml       aml     aml     aml     aml  normal     aml
# 284         284     aml       aml     aml     aml     aml     aml     aml
# 285         285  normal    normal  normal  normal  normal  normal  normal
# 286         286  normal    normal  normal  normal  normal  normal  normal
# 287         287  normal    normal  normal  normal  normal  normal  normal
# 288         288  normal    normal  normal  normal  normal  normal  normal
# 289         289  normal    normal  normal  normal  normal  normal  normal
# 290         290  normal    normal  normal  normal  normal  normal  normal
# 291         291  normal    normal  normal  normal  normal  normal  normal
# 292         292  normal    normal  normal  normal  normal  normal  normal
# 293         293  normal    normal  normal  normal  normal  normal  normal
# 294         294  normal    normal  normal  normal  normal  normal  normal
# 295         295  normal    normal  normal  normal  normal  normal  normal
# 296         296  normal    normal  normal  normal  normal  normal  normal
# 297         297  normal    normal  normal  normal  normal  normal  normal
# 298         298     aml       aml     aml     aml     aml     aml     aml
# 299         299  normal    normal  normal  normal  normal  normal  normal
# 300         300  normal    normal  normal  normal  normal  normal  normal
# 301         301  normal    normal  normal  normal  normal  normal  normal
# 302         302  normal    normal  normal  normal  normal  normal  normal
# 303         303  normal    normal  normal  normal  normal  normal  normal
# 304         304  normal    normal  normal  normal  normal  normal  normal
# 305         305  normal    normal  normal  normal  normal  normal  normal
# 306         306  normal    normal  normal  normal  normal  normal  normal
# 307         307  normal    normal  normal  normal  normal  normal  normal
# 308         308  normal    normal  normal  normal  normal  normal  normal
# 309         309  normal    normal  normal  normal  normal  normal  normal
# 310         310  normal    normal  normal  normal  normal  normal  normal
# 311         311  normal    normal  normal  normal  normal  normal  normal
# 312         312  normal    normal  normal  normal  normal  normal  normal
# 313         313     aml       aml     aml     aml     aml     aml     aml
# 314         314  normal    normal  normal  normal  normal  normal  normal
# 315         315  normal    normal  normal  normal  normal  normal  normal
# 316         316  normal    normal  normal  normal  normal  normal  normal
# 317         317  normal    normal  normal  normal  normal  normal  normal
# 318         318  normal    normal  normal  normal  normal  normal  normal
# 319         319  normal    normal  normal  normal  normal  normal  normal
# 320         320  normal    normal  normal  normal  normal  normal  normal
# 321         321  normal    normal  normal  normal  normal  normal  normal
# 322         322  normal    normal  normal  normal  normal  normal  normal
# 323         323  normal    normal  normal  normal  normal  normal  normal
# 324         324  normal    normal  normal  normal  normal  normal  normal
# 325         325     aml       aml     aml     aml  normal     aml     aml
# 326         326  normal    normal  normal  normal  normal  normal  normal
# 327         327     aml    normal  normal  normal  normal  normal  normal
# 328         328  normal    normal  normal  normal  normal  normal  normal
# 329         329  normal    normal  normal  normal  normal  normal  normal
# 330         330  normal    normal  normal  normal  normal  normal  normal
# 331         331  normal    normal  normal  normal  normal  normal  normal
# 332         332  normal    normal  normal  normal  normal  normal  normal
# 333         333  normal    normal  normal  normal  normal  normal  normal
# 334         334  normal    normal  normal  normal  normal  normal  normal
# 335         335  normal    normal  normal  normal  normal  normal  normal
# 336         336     aml       aml     aml     aml     aml     aml     aml
# 337         337  normal    normal  normal  normal  normal  normal  normal
# 338         338  normal    normal  normal  normal  normal  normal  normal
# 339         339     aml       aml  normal  normal  normal     aml  normal
# 340         340  normal    normal  normal  normal  normal  normal  normal
# 341         341  normal    normal  normal  normal  normal  normal  normal
# 342         342  normal    normal  normal  normal  normal  normal  normal
# 343         343     aml       aml     aml     aml     aml     aml     aml
# 344         344  normal    normal  normal  normal  normal  normal  normal
# 345         345  normal    normal  normal  normal  normal  normal  normal
# 346         346  normal    normal  normal  normal  normal  normal  normal
# 347         347     aml       aml     aml     aml     aml     aml     aml
# 348         348  normal    normal  normal  normal  normal  normal  normal
# 349         349  normal    normal  normal  normal  normal  normal  normal
# 350         350  normal    normal  normal  normal  normal  normal  normal
# 351         351  normal    normal  normal  normal  normal  normal  normal
# 352         352  normal    normal  normal  normal  normal  normal  normal
# 353         353  normal    normal  normal  normal  normal  normal  normal
# 354         354  normal    normal  normal  normal  normal  normal  normal
# 355         355  normal    normal  normal  normal  normal  normal  normal
# 356         356  normal    normal  normal  normal  normal  normal  normal
# 357         357  normal    normal  normal  normal  normal  normal  normal
# 358         358  normal    normal  normal  normal  normal  normal  normal
#
#           6       7
# 0    normal  normal
# 1    normal  normal
# 2    normal  normal
# 3    normal  normal
# 4       aml  normal
# 5    normal  normal
# 6    normal  normal
# 7    normal  normal
# 8       aml     aml
# 9    normal  normal
# 10   normal  normal
# 11   normal  normal
# 12   normal  normal
# 13   normal  normal
# 14   normal  normal
# 15   normal  normal
# 16   normal  normal
# 17   normal  normal
# 18   normal  normal
# 19   normal  normal
# 20   normal  normal
# 21   normal  normal
# 22   normal  normal
# 23   normal  normal
# 24   normal  normal
# 25      aml     aml
# 26   normal  normal
# 27   normal  normal
# 28   normal  normal
# 29   normal  normal
# 30   normal  normal
# 31   normal  normal
# 32      aml     aml
# 33   normal  normal
# 34   normal  normal
# 35   normal  normal
# 36      aml     aml
# 37   normal  normal
# 38   normal  normal
# 39   normal  normal
# 40   normal  normal
# 41   normal  normal
# 42   normal  normal
# 43   normal  normal
# 44   normal  normal
# 45   normal  normal
# 46   normal  normal
# 47   normal  normal
# 48      aml     aml
# 49   normal  normal
# 50   normal  normal
# 51   normal  normal
# 52   normal  normal
# 53   normal  normal
# 54   normal  normal
# 55   normal  normal
# 56   normal  normal
# 57      aml     aml
# 58   normal  normal
# 59   normal  normal
# 60   normal  normal
# 61   normal  normal
# 62   normal  normal
# 63   normal  normal
# 64   normal  normal
# 65   normal  normal
# 66      aml     aml
# 67   normal  normal
# 68   normal  normal
# 69   normal  normal
# 70   normal  normal
# 71   normal  normal
# 72   normal  normal
# 73   normal  normal
# 74   normal  normal
# 75   normal  normal
# 76   normal  normal
# 77   normal  normal
# 78   normal  normal
# 79   normal  normal
# 80   normal  normal
# 81   normal  normal
# 82   normal  normal
# 83   normal  normal
# 84   normal  normal
# 85   normal  normal
# 86   normal  normal
# 87      aml     aml
# 88      aml     aml
# 89   normal  normal
# 90   normal  normal
# 91   normal  normal
# 92   normal  normal
# 93   normal  normal
# 94      aml     aml
# 95   normal  normal
# 96   normal  normal
# 97   normal  normal
# 98   normal  normal
# 99   normal  normal
# 100  normal  normal
# 101  normal  normal
# 102     aml     aml
# 103  normal  normal
# 104     aml     aml
# 105  normal  normal
# 106  normal  normal
# 107  normal  normal
# 108  normal  normal
# 109  normal  normal
# 110  normal  normal
# 111  normal  normal
# 112  normal  normal
# 113  normal  normal
# 114  normal  normal
# 115  normal  normal
# 116     aml     aml
# 117  normal  normal
# 118  normal  normal
# 119  normal  normal
# 120  normal  normal
# 121  normal  normal
# 122  normal  normal
# 123  normal  normal
# 124  normal  normal
# 125  normal  normal
# 126  normal  normal
# 127  normal  normal
# 128  normal  normal
# 129  normal  normal
# 130  normal  normal
# 131  normal  normal
# 132  normal  normal
# 133     aml     aml
# 134  normal  normal
# 135  normal  normal
# 136  normal  normal
# 137  normal  normal
# 138  normal  normal
# 139  normal  normal
# 140  normal  normal
# 141  normal  normal
# 142  normal  normal
# 143  normal  normal
# 144  normal  normal
# 145  normal  normal
# 146  normal  normal
# 147  normal  normal
# 148  normal  normal
# 149  normal  normal
# 150     aml     aml
# 151  normal  normal
# 152  normal  normal
# 153  normal  normal
# 154  normal  normal
# 155  normal  normal
# 156  normal  normal
# 157  normal  normal
# 158  normal  normal
# 159  normal  normal
# 160  normal  normal
# 161  normal  normal
# 162  normal  normal
# 163  normal  normal
# 164     aml     aml
# 165  normal  normal
# 166  normal  normal
# 167  normal  normal
# 168  normal  normal
# 169  normal  normal
# 170  normal  normal
# 171     aml     aml
# 172  normal  normal
# 173     aml     aml
# 174  normal  normal
# 175  normal  normal
# 176  normal  normal
# 177  normal  normal
# 178  normal  normal
# 179  normal  normal
# 180  normal  normal
# 181  normal  normal
# 182  normal  normal
# 183  normal  normal
# 184  normal  normal
# 185  normal  normal
# 186  normal  normal
# 187  normal  normal
# 188  normal  normal
# 189  normal  normal
# 190  normal  normal
# 191  normal  normal
# 192  normal  normal
# 193  normal  normal
# 194  normal  normal
# 195  normal  normal
# 196  normal  normal
# 197  normal  normal
# 198  normal  normal
# 199  normal  normal
# 200  normal  normal
# 201  normal  normal
# 202     aml     aml
# 203  normal  normal
# 204     aml     aml
# 205  normal  normal
# 206  normal  normal
# 207  normal  normal
# 208  normal  normal
# 209  normal  normal
# 210     aml     aml
# 211  normal  normal
# 212  normal  normal
# 213  normal  normal
# 214  normal  normal
# 215  normal  normal
# 216  normal  normal
# 217  normal  normal
# 218     aml     aml
# 219  normal  normal
# 220     aml     aml
# 221  normal  normal
# 222  normal  normal
# 223  normal  normal
# 224  normal  normal
# 225  normal  normal
# 226     aml     aml
# 227  normal  normal
# 228  normal  normal
# 229  normal  normal
# 230  normal  normal
# 231  normal  normal
# 232  normal  normal
# 233  normal  normal
# 234  normal  normal
# 235     aml  normal
# 236  normal  normal
# 237  normal  normal
# 238     aml  normal
# 239  normal  normal
# 240  normal  normal
# 241  normal  normal
# 242  normal  normal
# 243  normal  normal
# 244  normal  normal
# 245  normal  normal
# 246  normal  normal
# 247  normal  normal
# 248  normal  normal
# 249  normal  normal
# 250  normal  normal
# 251  normal  normal
# 252  normal  normal
# 253  normal  normal
# 254  normal  normal
# 255  normal  normal
# 256  normal  normal
# 257  normal  normal
# 258  normal  normal
# 259  normal  normal
# 260     aml     aml
# 261     aml     aml
# 262  normal  normal
# 263  normal  normal
# 264  normal  normal
# 265  normal  normal
# 266  normal  normal
# 267  normal  normal
# 268     aml     aml
# 269  normal  normal
# 270  normal  normal
# 271  normal  normal
# 272  normal  normal
# 273  normal  normal
# 274  normal  normal
# 275  normal  normal
# 276  normal  normal
# 277  normal  normal
# 278  normal  normal
# 279  normal  normal
# 280  normal  normal
# 281  normal  normal
# 282  normal  normal
# 283     aml     aml
# 284     aml     aml
# 285  normal  normal
# 286  normal  normal
# 287  normal  normal
# 288  normal  normal
# 289  normal  normal
# 290  normal  normal
# 291  normal  normal
# 292  normal  normal
# 293  normal  normal
# 294  normal  normal
# 295  normal  normal
# 296  normal  normal
# 297  normal  normal
# 298     aml     aml
# 299  normal  normal
# 300  normal  normal
# 301  normal  normal
# 302  normal  normal
# 303  normal  normal
# 304  normal  normal
# 305  normal  normal
# 306  normal  normal
# 307  normal  normal
# 308  normal  normal
# 309  normal  normal
# 310  normal  normal
# 311  normal  normal
# 312  normal  normal
# 313     aml     aml
# 314  normal  normal
# 315  normal  normal
# 316  normal  normal
# 317  normal  normal
# 318  normal  normal
# 319  normal  normal
# 320  normal  normal
# 321  normal  normal
# 322  normal  normal
# 323  normal  normal
# 324  normal  normal
# 325     aml     aml
# 326  normal  normal
# 327  normal  normal
# 328  normal  normal
# 329  normal  normal
# 330  normal  normal
# 331  normal  normal
# 332  normal  normal
# 333  normal  normal
# 334  normal  normal
# 335  normal  normal
# 336     aml     aml
# 337  normal  normal
# 338  normal  normal
# 339     aml  normal
# 340  normal  normal
# 341  normal  normal
# 342  normal  normal
# 343     aml     aml
# 344  normal  normal
# 345  normal  normal
# 346  normal  normal
# 347     aml     aml
# 348  normal  normal
# 349  normal  normal
# 350  normal  normal
# 351  normal  normal
# 352  normal  normal
# 353  normal  normal
# 354  normal  normal
# 355  normal  normal
# 356  normal  normal
# 357  normal  normal
# 358  normal  normal

# %%
data = all_combos(2,2)
data.shape
# Out:
# tube complete - 18.0230833332min
# (359L, 1295L)

# %%
data = all_combos(2,3)
data.shape
# Out:
# tube complete - 34.8737333337min
# (359L, 9188L)

# %%
data = all_combos(2,4)
data.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2090bcd90b57> in <module>()
# ----> 1 data = all_combos(2,4)
#       2 data.shape
#
# <ipython-input-12-eb41d1f3c73f> in all_combos(tube, n_d)
#      63     for markers in combinations(range(1,8),n_d):
#      64         if firstcombo == True:
# ---> 65             tube_data = get_combo(tube,markers)
#      66             firstcombo = False
#      67         else:
#
# <ipython-input-12-eb41d1f3c73f> in get_combo(tube, markers)
#      39
#      40     #start = time.time()
# ---> 41     combo_hist = pd.DataFrame(histo(get_csv(1,tube,markers)),index=[0])
#      42
#      43     for ptnum in range(2,360):
#
# <ipython-input-12-eb41d1f3c73f> in histo(data)
#      17     d = defaultdict(int)
#      18     for cell in data:
# ---> 19         d[tuple(cell)] += 1
#      20     return d
#      21
#
# KeyboardInterrupt:

# %%
Y = pd.read_csv('C:\\python27\\CAPSTONE\\Y.csv')
    
    #Y = Y.drop(339,axis = 0).reset_index(drop = True)
    #data = np.delete(data,339,0)
XTRAIN = data
YTRAIN = Y
hiC = 6
lowC = -6
        
f1_scorer = metrics.make_scorer(metrics.f1_score, labels=['aml','normal'], pos_label='aml')
algorithm, params, scoring = svm.LinearSVC(), {'C': np.logspace(lowC, hiC, hiC-lowC+1, endpoint=True)}, f1_scorer
cv = model_selection.StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)
results = gridsearch(XTRAIN, YTRAIN, algorithm, params, cv, scoring)

# %%
data = all_combos(2,5)
data.shape
# Out:
# tube complete - 43.9361833334min
# (359L, 32384L)

# %%
data = all_combos(2,6)
data.shape
# Out:
# tube complete - 16.1268166661min
# (359L, 19158L)

# %%
data = all_combos(2,7)
data.shape
# Out:
# tube complete - 2.17625000079min
# (359L, 4294L)
